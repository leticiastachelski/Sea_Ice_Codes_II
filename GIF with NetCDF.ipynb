# %%
from netCDF4 import Dataset
import xarray as xr
import os, glob
import imageio.v2 as imageio
import matplotlib.pyplot as plt

png_dir1 = '/home/leticia/Documentos/leticia_dados_CMIP/dados_CMIP5/IPSL/TSM/'
png_dir = '/home/leticia/Documentos/leticia_dados_CMIP/dados_CMIP5/IPSL/TSM/meantsm.nc'
airtemps = Dataset(png_dir, mode='r')

max_temp = airtemps.variables['tos'][1:12,:,:].max()
min_temp = airtemps.variables['tos'][1:12,:,:].min()  

# Plots with Fixed colorbar    
for i in np.arange(12):
    plt.contourf(airtemps.variables['tos'][i,:,:], levels = np.linspace(min_temp,max_temp,12)), plt.colorbar()
    plt.figure()
    plt.savefig(png_dir1 + 'fixed_cb_air_temp_' + str(i) +'.jpg')

fixed_cb_images = glob.glob(png_dir1 + ('fix*'))  

fix = [imageio.imread(file) for file in fixed_cb_images]

imageio.mimsave(png_dir1 + 'movie_fixed_cb.gif', fix, fps = 12)

# %%
from netCDF4 import Dataset
import xarray as xr
import os, glob
import imageio

png_dir = '/home/leticia/Documentos/leticia_dados_CMIP/dados_CMIP5/IPSL/TSM/meantsm.nc'
airtemps = Dataset(png_dir, mode='r')

max_temp = airtemps.variables['tos'][:,:,:].max()
min_temp = airtemps.variables['tos'][:,:,:].min() 
plt.contourf(airtemps.variables['tos'][i,:,:], levels = np.linspace(min_temp,max_temp,24)), plt.colorbar()
plt.figure()
