# %%
#-----------------------------------------
from netCDF4 import Dataset
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap
import matplotlib.colors
#-----------------------------------------
fig=plt.figure(figsize=(18,5), dpi=100)

# %%
#-----------------------------------------
sic = '/home/leticia/Documentos/leticia_dados_CMIP/dados_artigo_programs/todos netcdfs/CMIP5_media.nc'
fh = Dataset(sic, mode='r')
lons = fh.variables['lon'][:]
lats = fh.variables['lat'][:]
sic = fh.variables['sic'][2,:,:]
#sic = fh.variables['icec'][9,:,:]
#sic = fh.variables['siconc'][2,:,:]
sic_units = fh.variables['sic'].units
fh.close()
lon_0 = lons.mean()
lat_0 = lats.mean()
#-----------------------------------------
m= Basemap(projection='spstere',resolution='f',boundinglat=-50, round=True,lon_0=180)
#-----------------------------------------
lon, lat = np.meshgrid(lons, lats)
xi, yi = m(lon, lat)
levels = np.linspace(-100,100,19, endpoint=True, dtype=int)
ax = fig.add_subplot(221)
ax.set_title('a) CMIP5',  y=1.08, loc='left')
norm= matplotlib.colors.Normalize()

def custom_div_cmap(numcolors=11, name='custom_div_cmap',
                    mincol='white', midcol='red', maxcol='darkred'):
    """ Create a custom diverging colormap with three colors
    
    Default is blue to white to red with 11 colors.  Colors can be specified
    in any way understandable by matplotlib.colors.ColorConverter.to_rgb()
    """

    from matplotlib.colors import LinearSegmentedColormap 
    
    cmap = LinearSegmentedColormap.from_list(name=name, 
                                             colors =[mincol, midcol, maxcol],
                                             N=numcolors)
    return cmap

bwr_custom = custom_div_cmap(11)
sic = m.contourf(xi,yi,sic, cmap=bwr_custom, levels=[0,15,25,50,75,100],extend='both',norm=norm)
#----------------------------------------
m.drawlsmask()
m.drawcoastlines()
m.drawparallels(np.arange(-90.,90.,10.),color='silver')#,labels=[True,True,False,False])
m.drawmeridians(np.arange(0.,360.,20.),color='silver')#,labels=[True,True,True,True])
# Out:
# /home/leticia/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:14: MatplotlibDeprecationWarning:
# The dedent function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use inspect.cleandoc instead.
# {0.0: ([<matplotlib.lines.Line2D at 0x7f3e1d092f50>], []),
#  20.0: ([<matplotlib.lines.Line2D at 0x7f3e1d092f90>], []),
#  40.0: ([<matplotlib.lines.Line2D at 0x7f3e1d092350>], []),
#  60.0: ([<matplotlib.lines.Line2D at 0x7f3e1d087f10>], []),
#  80.0: ([<matplotlib.lines.Line2D at 0x7f3e1d092810>], []),
#  100.0: ([<matplotlib.lines.Line2D at 0x7f3e1d087990>], []),
#  120.0: ([<matplotlib.lines.Line2D at 0x7f3e1d063e50>], []),
#  140.0: ([<matplotlib.lines.Line2D at 0x7f3e1d087e90>], []),
#  160.0: ([<matplotlib.lines.Line2D at 0x7f3e1d0638d0>], []),
#  180.0: ([<matplotlib.lines.Line2D at 0x7f3e25d67d90>], []),
#  200.0: ([<matplotlib.lines.Line2D at 0x7f3e1d063dd0>], []),
#  220.0: ([<matplotlib.lines.Line2D at 0x7f3e25d67810>], []),
#  240.0: ([<matplotlib.lines.Line2D at 0x7f3e25d74c90>], []),
#  260.0: ([<matplotlib.lines.Line2D at 0x7f3e25d67d10>], []),
#  280.0: ([<matplotlib.lines.Line2D at 0x7f3e25d74710>], []),
#  300.0: ([<matplotlib.lines.Line2D at 0x7f3e25d80bd0>], []),
#  320.0: ([<matplotlib.lines.Line2D at 0x7f3e25d74c10>], []),
#  340.0: ([<matplotlib.lines.Line2D at 0x7f3e25d80650>], [])}

# %%
sic = '/home/leticia/Documentos/leticia_dados_CMIP/dados_artigo_programs/todos netcdfs/CMIP6_media.nc'
fh = Dataset(sic, mode='r')
lons = fh.variables['lon'][:]
lats = fh.variables['lat'][:]
sic = fh.variables['siconc'][2,:,:]
#sic = fh.variables['icec'][9,:,:]
#sic = fh.variables['siconc'][2,:,:]
sic_units = fh.variables['siconc'].units
fh.close()
lon_0 = lons.mean()
lat_0 = lats.mean()
#-----------------------------------------
m= Basemap(projection='spstere',resolution='f',boundinglat=-50, round=True,lon_0=180)
#-----------------------------------------
lon, lat = np.meshgrid(lons, lats)
xi, yi = m(lon, lat)
levels = np.linspace(-100,100,19,  endpoint=True, dtype=int)
ax = fig.add_subplot(222)
ax.set_title('b) CMIP6',  y=1.08, loc='left')
norm= matplotlib.colors.Normalize()

def custom_div_cmap(numcolors=11, name='custom_div_cmap',
                    mincol='white', midcol='red', maxcol='darkred'):
    """ Create a custom diverging colormap with three colors
    
    Default is blue to white to red with 11 colors.  Colors can be specified
    in any way understandable by matplotlib.colors.ColorConverter.to_rgb()
    """

    from matplotlib.colors import LinearSegmentedColormap 
    
    cmap = LinearSegmentedColormap.from_list(name=name, 
                                             colors =[mincol, midcol, maxcol],
                                             N=numcolors)
    return cmap

bwr_custom = custom_div_cmap(11)
sic = m.contourf(xi,yi,sic, cmap=bwr_custom, levels=[0,15,25,50,75,100],extend='both',norm=norm)
#----------------------------------------
#----------------------------------------
m.drawlsmask()
m.drawcoastlines()
m.drawparallels(np.arange(-90.,90.,10.),color='silver')#,labels=[True,True,False,False])
m.drawmeridians(np.arange(0.,360.,20.),color='silver')#,labels=[True,True,True,True])
# Out:
# /home/leticia/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: MatplotlibDeprecationWarning:
# The dedent function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use inspect.cleandoc instead.
#   del sys.path[0]
# {0.0: ([<matplotlib.lines.Line2D at 0x7f3e34d2ab90>], []),
#  20.0: ([<matplotlib.lines.Line2D at 0x7f3e18785e50>], []),
#  40.0: ([<matplotlib.lines.Line2D at 0x7f3e18785ed0>], []),
#  60.0: ([<matplotlib.lines.Line2D at 0x7f3e34d4dad0>], []),
#  80.0: ([<matplotlib.lines.Line2D at 0x7f3e34d4df90>], []),
#  100.0: ([<matplotlib.lines.Line2D at 0x7f3e34d4dfd0>], []),
#  120.0: ([<matplotlib.lines.Line2D at 0x7f3e34d4da50>], []),
#  140.0: ([<matplotlib.lines.Line2D at 0x7f3e1823df10>], []),
#  160.0: ([<matplotlib.lines.Line2D at 0x7f3e34d4df50>], []),
#  180.0: ([<matplotlib.lines.Line2D at 0x7f3e1823d990>], []),
#  200.0: ([<matplotlib.lines.Line2D at 0x7f3e18244e10>], []),
#  220.0: ([<matplotlib.lines.Line2D at 0x7f3e1823de90>], []),
#  240.0: ([<matplotlib.lines.Line2D at 0x7f3e182448d0>], []),
#  260.0: ([<matplotlib.lines.Line2D at 0x7f3e1824dd50>], []),
#  280.0: ([<matplotlib.lines.Line2D at 0x7f3e18244d90>], []),
#  300.0: ([<matplotlib.lines.Line2D at 0x7f3e1824d7d0>], []),
#  320.0: ([<matplotlib.lines.Line2D at 0x7f3e18254c90>], []),
#  340.0: ([<matplotlib.lines.Line2D at 0x7f3e1824dcd0>], [])}

# %%
sic = '/home/leticia/Documentos/leticia_dados_CMIP/dados_artigo_programs/todos netcdfs/sate_mean.nc'
fh = Dataset(sic, mode='r')
lons = fh.variables['lon'][:]
lats = fh.variables['lat'][:]
sic = fh.variables['icec'][2,:,:]
#sic = fh.variables['icec'][9,:,:]
#sic = fh.variables['siconc'][2,:,:]
sic_units = fh.variables['icec'].units
fh.close()
lon_0 = lons.mean()
lat_0 = lats.mean()
#-----------------------------------------
m= Basemap(projection='spstere',resolution='f',boundinglat=-50, round=True,lon_0=180)
#-----------------------------------------
lon, lat = np.meshgrid(lons, lats)
xi, yi = m(lon, lat)
levels = np.linspace(-100,100,19, endpoint=True, dtype=int)
ax = fig.add_subplot(2,2,(3,4))
ax.set_title('c) Observado',  y=1.08, loc='left')
norm= matplotlib.colors.Normalize()

def custom_div_cmap(numcolors=11, name='custom_div_cmap',
                    mincol='white', midcol='red', maxcol='darkred'):
    """ Create a custom diverging colormap with three colors
    
    Default is blue to white to red with 11 colors.  Colors can be specified
    in any way understandable by matplotlib.colors.ColorConverter.to_rgb()
    """

    from matplotlib.colors import LinearSegmentedColormap 
    
    cmap = LinearSegmentedColormap.from_list(name=name, 
                                             colors =[mincol, midcol, maxcol],
                                             N=numcolors)
    return cmap

bwr_custom = custom_div_cmap(11)
sic = m.contourf(xi,yi,sic, cmap=bwr_custom, levels=[0,15,25,50,75,100],extend='both',norm=norm)
#----------------------------------------
m.drawlsmask()
m.drawcoastlines()
m.drawparallels(np.arange(-90.,90.,10.),color='silver')#,labels=[True,True,False,False])
m.drawmeridians(np.arange(0.,360.,20.),color='silver')#,labels=[True,True,True,True])
# Out:
# /home/leticia/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: MatplotlibDeprecationWarning:
# The dedent function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use inspect.cleandoc instead.
#   del sys.path[0]
# {0.0: ([<matplotlib.lines.Line2D at 0x7f3e26a76e90>], []),
#  20.0: ([<matplotlib.lines.Line2D at 0x7f3e1b4fa190>], []),
#  40.0: ([<matplotlib.lines.Line2D at 0x7f3e26a76210>], []),
#  60.0: ([<matplotlib.lines.Line2D at 0x7f3e26a7add0>], []),
#  80.0: ([<matplotlib.lines.Line2D at 0x7f3e26a766d0>], []),
#  100.0: ([<matplotlib.lines.Line2D at 0x7f3e26a7a850>], []),
#  120.0: ([<matplotlib.lines.Line2D at 0x7f3e26a86d10>], []),
#  140.0: ([<matplotlib.lines.Line2D at 0x7f3e26a7ad50>], []),
#  160.0: ([<matplotlib.lines.Line2D at 0x7f3e26a86790>], []),
#  180.0: ([<matplotlib.lines.Line2D at 0x7f3e26a94c50>], []),
#  200.0: ([<matplotlib.lines.Line2D at 0x7f3e26a86c90>], []),
#  220.0: ([<matplotlib.lines.Line2D at 0x7f3e26a946d0>], []),
#  240.0: ([<matplotlib.lines.Line2D at 0x7f3e26a24b50>], []),
#  260.0: ([<matplotlib.lines.Line2D at 0x7f3e26a94bd0>], []),
#  280.0: ([<matplotlib.lines.Line2D at 0x7f3e26a245d0>], []),
#  300.0: ([<matplotlib.lines.Line2D at 0x7f3e26a24ad0>], []),
#  320.0: ([<matplotlib.lines.Line2D at 0x7f3e26a35f90>], []),
#  340.0: ([<matplotlib.lines.Line2D at 0x7f3e18232c10>], [])}

# %%
cbar_ax = fig.add_axes([0.92, 0.35, 0.01, 0.3],title='')
fig.colorbar(sic,cax=cbar_ax)

# %%
plt.show()
