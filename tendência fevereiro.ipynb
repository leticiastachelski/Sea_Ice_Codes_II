# %%
#-----------------------------------------
from netCDF4 import Dataset
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap
import matplotlib.colors
#-----------------------------------------
fig=plt.figure(figsize=(20,20), dpi=300)
#-----------------------------------------
sic = '/home/leticia/Documentos/leticia_dados_CMIP/dados_CMIP5/ACCESS/tendencia/fevregres.nc'
fh = Dataset(sic, mode='r')
lons = fh.variables['lon'][:]
lats = fh.variables['lat'][:]
sic = fh.variables['sic'][0,:,:]
#sic = fh.variables['icec'][9,:,:]
#sic = fh.variables['siconc'][0,:,:]
sic_units = fh.variables['sic'].units
fh.close()
lon_0 = lons.mean()
lat_0 = lats.mean()
#-----------------------------------------
m= Basemap(projection='spstere',resolution='f',boundinglat=-50, round=True,lon_0=180)
#-----------------------------------------
lon, lat = np.meshgrid(lons, lats)
xi, yi = m(lon, lat)
levels = np.linspace(-4,4,19, endpoint=True, dtype=int)
ax = fig.add_subplot(4,6,1)
ax.set_title('a) ACCESS1-0',  y=1.08, loc='left')
norm= matplotlib.colors.Normalize()

def custom_div_cmap(numcolors=11, name='custom_div_cmap',
                    mincol='red', midcol='white', maxcol='blue'):
    """ Create a custom diverging colormap with three colors
    
    Default is blue to white to red with 11 colors.  Colors can be specified
    in any way understandable by matplotlib.colors.ColorConverter.to_rgb()
    """

    from matplotlib.colors import LinearSegmentedColormap 
    
    cmap = LinearSegmentedColormap.from_list(name=name, 
                                             colors =[mincol, midcol, maxcol],
                                             N=numcolors)
    return cmap

bwr_custom = custom_div_cmap(11)
sic = m.contourf(xi,yi,sic, cmap=bwr_custom, levels=[-4,-3,-2,-1,-0.5,0,0.5,1,2,3,4],extend='both',norm=norm)
#----------------------------------------
m.drawlsmask()
m.drawcoastlines()
m.drawparallels(np.arange(-90.,90.,10.),color='silver')#,labels=[True,True,False,False])
m.drawmeridians(np.arange(0.,360.,20.),color='silver')#,labels=[True,True,True,True])
#----------------------------------------
#----------------------------------------
sic = '/home/leticia/Documentos/leticia_dados_CMIP/dados_CMIP6/ACCESS/tendencia/fevregres.nc'
fh = Dataset(sic, mode='r')
lons = fh.variables['lon'][:]
lats = fh.variables['lat'][:]
sic = fh.variables['siconc'][0,:,:]
#sic = fh.variables['icec'][9,:,:]
#sic = fh.variables['siconc'][0,:,:]
sic_units = fh.variables['siconc'].units
fh.close()
lon_0 = lons.mean()
lat_0 = lats.mean()
#-----------------------------------------
m= Basemap(projection='spstere',resolution='f',boundinglat=-50, round=True,lon_0=180)
#-----------------------------------------
lon, lat = np.meshgrid(lons, lats)
xi, yi = m(lon, lat)
levels = np.linspace(-4,4,19,  endpoint=True, dtype=int)
ax = fig.add_subplot(4,6,2)
ax.set_title('b) ACCESS-ESM1-5',  y=1.08, loc='left')
norm= matplotlib.colors.Normalize()

bwr_custom = custom_div_cmap(11)
sic = m.contourf(xi,yi,sic, cmap=bwr_custom, levels=[-4,-3,-2,-1,-0.5,0,0.5,1,2,3,4],extend='both',norm=norm)
#----------------------------------------
#----------------------------------------
m.drawlsmask()
m.drawcoastlines()
m.drawparallels(np.arange(-90.,90.,10.),color='silver')#,labels=[True,True,False,False])
m.drawmeridians(np.arange(0.,360.,20.),color='silver')#,labels=[True,True,True,True])

sic = '/home/leticia/Documentos/leticia_dados_CMIP/dados_CMIP5/CANESM/tendencia/fevregres.nc'
fh = Dataset(sic, mode='r')
lons = fh.variables['lon'][:]
lats = fh.variables['lat'][:]
sic = fh.variables['sic'][0,:,:]
#sic = fh.variables['icec'][9,:,:]
#sic = fh.variables['siconc'][0,:,:]
sic_units = fh.variables['sic'].units
fh.close()
lon_0 = lons.mean()
lat_0 = lats.mean()
#-----------------------------------------
m= Basemap(projection='spstere',resolution='f',boundinglat=-50, round=True,lon_0=180)
#-----------------------------------------
lon, lat = np.meshgrid(lons, lats)
xi, yi = m(lon, lat)
levels = np.linspace(-4,4,19, endpoint=True, dtype=int)
ax = fig.add_subplot(4,6,3)
ax.set_title('c) CanESM2',  y=1.08, loc='left')
norm= matplotlib.colors.Normalize()

bwr_custom = custom_div_cmap(11)
sic = m.contourf(xi,yi,sic, cmap=bwr_custom, levels=[-4,-3,-2,-1,-0.5,0,0.5,1,2,3,4],extend='both',norm=norm)
#----------------------------------------
m.drawlsmask()
m.drawcoastlines()
m.drawparallels(np.arange(-90.,90.,10.),color='silver')#,labels=[True,True,False,False])
m.drawmeridians(np.arange(0.,360.,20.),color='silver')#,labels=[True,True,True,True])
#----------------------------------------
sic = '/home/leticia/Documentos/leticia_dados_CMIP/dados_CMIP6/CANESM/tendencia/fevregres.nc'
fh = Dataset(sic, mode='r')
lons = fh.variables['lon'][:]
lats = fh.variables['lat'][:]
sic = fh.variables['siconc'][0,:,:]
#sic = fh.variables['icec'][9,:,:]
#sic = fh.variables['siconc'][0,:,:]
sic_units = fh.variables['siconc'].units
fh.close()
lon_0 = lons.mean()
lat_0 = lats.mean()
#-----------------------------------------
m= Basemap(projection='spstere',resolution='f',boundinglat=-50, round=True,lon_0=180)
#-----------------------------------------
lon, lat = np.meshgrid(lons, lats)
xi, yi = m(lon, lat)
levels = np.linspace(-4,4,19, endpoint=True, dtype=int)
ax = fig.add_subplot(4,6,4)
ax.set_title('d) CanESM5',  y=1.08, loc='left')
norm= matplotlib.colors.Normalize()

bwr_custom = custom_div_cmap(11)
sic = m.contourf(xi,yi,sic, cmap=bwr_custom, levels=[-4,-3,-2,-1,-0.5,0,0.5,1,2,3,4],extend='both',norm=norm)
#----------------------------------------
m.drawlsmask()
m.drawcoastlines()
m.drawparallels(np.arange(-90.,90.,10.),color='silver')#,labels=[True,True,False,False])
m.drawmeridians(np.arange(0.,360.,20.),color='silver')#,labels=[True,True,True,True])

#----------------------------------------
sic = '/home/leticia/Documentos/leticia_dados_CMIP/dados_CMIP5/EC-EARTH/tendencia/fevregres.nc'
fh = Dataset(sic, mode='r')
lons = fh.variables['lon'][:]
lats = fh.variables['lat'][:]
sic = fh.variables['sic'][0,:,:]
#sic = fh.variables['icec'][9,:,:]
#sic = fh.variables['siconc'][0,:,:]
sic_units = fh.variables['sic'].units
fh.close()
lon_0 = lons.mean()
lat_0 = lats.mean()
#-----------------------------------------
m= Basemap(projection='spstere',resolution='f',boundinglat=-50, round=True,lon_0=180)
#-----------------------------------------
lon, lat = np.meshgrid(lons, lats)
xi, yi = m(lon, lat)
levels = np.linspace(-4,4,19, endpoint=True, dtype=int)
ax = fig.add_subplot(4,6,5)
ax.set_title('e) EC-EARTH ',  y=1.08, loc='left')
norm= matplotlib.colors.Normalize()

bwr_custom = custom_div_cmap(11)
sic = m.contourf(xi,yi,sic, cmap=bwr_custom, levels=[-4,-3,-2,-1,-0.5,0,0.5,1,2,3,4],extend='both',norm=norm)
#----------------------------------------
m.drawlsmask()
m.drawcoastlines()
m.drawparallels(np.arange(-90.,90.,10.),color='silver')#,labels=[True,True,False,False])
m.drawmeridians(np.arange(0.,360.,20.),color='silver')#,labels=[True,True,True,True])
#----------------------------------------

sic = '/home/leticia/Documentos/leticia_dados_CMIP/dados_CMIP6/EC-EARTH/tendencia/fevregres.nc'
fh = Dataset(sic, mode='r')
lons = fh.variables['lon'][:]
lats = fh.variables['lat'][:]
sic = fh.variables['siconc'][0,:,:]
#sic = fh.variables['icec'][9,:,:]
#sic = fh.variables['siconc'][0,:,:]
sic_units = fh.variables['siconc'].units
fh.close()
lon_0 = lons.mean()
lat_0 = lats.mean()
#-----------------------------------------
m= Basemap(projection='spstere',resolution='f',boundinglat=-50, round=True,lon_0=180)
#-----------------------------------------
lon, lat = np.meshgrid(lons, lats)
xi, yi = m(lon, lat)
levels = np.linspace(-4,4,19, endpoint=True, dtype=int)
ax = fig.add_subplot(4,6,6)
ax.set_title('f) EC-Earth3',  y=1.08, loc='left')
norm= matplotlib.colors.Normalize()

bwr_custom = custom_div_cmap(11)
sic = m.contourf(xi,yi,sic, cmap=bwr_custom, levels=[-4,-3,-2,-1,-0.5,0,0.5,1,2,3,4],extend='both',norm=norm)
#----------------------------------------
m.drawlsmask()
m.drawcoastlines()
m.drawparallels(np.arange(-90.,90.,10.),color='silver')#,labels=[True,True,False,False])
m.drawmeridians(np.arange(0.,360.,20.),color='silver')#,labels=[True,True,True,True])
#----------------------------------------
#----------------------------------------
sic = '/home/leticia/Documentos/leticia_dados_CMIP/dados_CMIP5/FGOALS/tendencia/fevregres.nc'
fh = Dataset(sic, mode='r')
lons = fh.variables['lon'][:]
lats = fh.variables['lat'][:]
sic = fh.variables['sic'][0,:,:]
#sic = fh.variables['icec'][9,:,:]
#sic = fh.variables['siconc'][0,:,:]
sic_units = fh.variables['sic'].units
fh.close()
lon_0 = lons.mean()
lat_0 = lats.mean()
#-----------------------------------------
m= Basemap(projection='spstere',resolution='f',boundinglat=-50, round=True,lon_0=180)
#-----------------------------------------
lon, lat = np.meshgrid(lons, lats)
xi, yi = m(lon, lat)
levels = np.linspace(-4,4,19,  endpoint=True, dtype=int)
ax = fig.add_subplot(4,6,7)
ax.set_title('g) FGOALS-g2',  y=1.08, loc='left')
norm= matplotlib.colors.Normalize()

bwr_custom = custom_div_cmap(11)
sic = m.contourf(xi,yi,sic, cmap=bwr_custom, levels=[-4,-3,-2,-1,-0.5,0,0.5,1,2,3,4],extend='both',norm=norm)
#----------------------------------------
m.drawlsmask()
m.drawcoastlines()
m.drawparallels(np.arange(-90.,90.,10.),color='silver')#,labels=[True,True,False,False])
m.drawmeridians(np.arange(0.,360.,20.),color='silver')#,labels=[True,True,True,True])
#----------------------------------------
#----------------------------------------
sic = '/home/leticia/Documentos/leticia_dados_CMIP/dados_CMIP6/FGOALS/tendencia/fevregres.nc'
fh = Dataset(sic, mode='r')
lons = fh.variables['lon'][:]
lats = fh.variables['lat'][:]
sic = fh.variables['siconc'][0,:,:]
#sic = fh.variables['icec'][9,:,:]
#sic = fh.variables['siconc'][0,:,:]
sic_units = fh.variables['siconc'].units
fh.close()
lon_0 = lons.mean()
lat_0 = lats.mean()
#-----------------------------------------
m= Basemap(projection='spstere',resolution='f',boundinglat=-50, round=True,lon_0=180)
#----------------------------------------
lon, lat = np.meshgrid(lons, lats)
xi, yi = m(lon, lat)
levels = np.linspace(-4,4,19, endpoint=True, dtype=int)
ax = fig.add_subplot(4,6,8)
ax.set_title('h) FGOALS-g3',  y=1.08, loc='left')
norm= matplotlib.colors.Normalize()

bwr_custom = custom_div_cmap(11)
sic = m.contourf(xi,yi,sic, cmap=bwr_custom, levels=[-4,-3,-2,-1,-0.5,0,0.5,1,2,3,4],extend='both',norm=norm)
#----------------------------------------
m.drawlsmask()
m.drawcoastlines()
m.drawparallels(np.arange(-90.,90.,10.),color='silver')#,labels=[True,True,False,False])
m.drawmeridians(np.arange(0.,360.,20.),color='silver')#,labels=[True,True,True,True])
#----------------------------------------
#----------------------------------------
sic = '/home/leticia/Documentos/leticia_dados_CMIP/dados_CMIP5/GDFL/tendencia/fevregres.nc'
fh = Dataset(sic, mode='r')
lons = fh.variables['lon'][:]
lats = fh.variables['lat'][:]
sic = fh.variables['sic'][0,:,:]
#sic = fh.variables['icec'][9,:,:]
#sic = fh.variables['siconc'][0,:,:]
sic_units = fh.variables['sic'].units
fh.close()
lon_0 = lons.mean()
lat_0 = lats.mean()
#-----------------------------------------
m= Basemap(projection='spstere',resolution='f',boundinglat=-50, round=True,lon_0=180)
#----------------------------------------
lon, lat = np.meshgrid(lons, lats)
xi, yi = m(lon, lat)
levels = np.linspace(-4,4,19, endpoint=True, dtype=int)
ax = fig.add_subplot(4,6,9)
ax.set_title('i) GFDL-CM3',  y=1.08, loc='left')
norm= matplotlib.colors.Normalize()

bwr_custom = custom_div_cmap(11)
sic = m.contourf(xi,yi,sic, cmap=bwr_custom, levels=[-4,-3,-2,-1,-0.5,0,0.5,1,2,3,4],extend='both',norm=norm)
#----------------------------------------
m.drawlsmask()
m.drawcoastlines()
m.drawparallels(np.arange(-90.,90.,10.),color='silver')#,labels=[True,True,False,False])
m.drawmeridians(np.arange(0.,360.,20.),color='silver')#,labels=[True,True,True,True])
#----------------------------------------
sic = '/home/leticia/Documentos/leticia_dados_CMIP/dados_CMIP6/GDFL/tendencia/fevregres.nc'
fh = Dataset(sic, mode='r')
lons = fh.variables['lon'][:]
lats = fh.variables['lat'][:]
sic = fh.variables['siconc'][0,:,:]
#sic = fh.variables['icec'][9,:,:]
#sic = fh.variables['siconc'][0,:,:]
sic_units = fh.variables['siconc'].units
fh.close()
lon_0 = lons.mean()
lat_0 = lats.mean()
#-----------------------------------------
m= Basemap(projection='spstere',resolution='f',boundinglat=-50, round=True,lon_0=180)
#-----------------------------------------
lon, lat = np.meshgrid(lons, lats)
xi, yi = m(lon, lat)
levels = np.linspace(-4,4,19, endpoint=True, dtype=int)
ax = fig.add_subplot(4,6,10)
ax.set_title('j) GFDL-CM4',  y=1.08, loc='left')
norm= matplotlib.colors.Normalize()

bwr_custom = custom_div_cmap(11)
sic = m.contourf(xi,yi,sic, cmap=bwr_custom, levels=[-4,-3,-2,-1,-0.5,0,0.5,1,2,3,4],extend='both',norm=norm)
#----------------------------------------
m.drawlsmask()
m.drawcoastlines()
m.drawparallels(np.arange(-90.,90.,10.),color='silver')#,labels=[True,True,False,False])
m.drawmeridians(np.arange(0.,360.,20.),color='silver')#,labels=[True,True,True,True])
#----------------------------------------
#----------------------------------------
#----------------------------------------
#-----------------------------------------
sic = '/home/leticia/Documentos/leticia_dados_CMIP/dados_CMIP5/giss/tendencia/fevregres.nc'
fh = Dataset(sic, mode='r')
lons = fh.variables['lon'][:]
lats = fh.variables['lat'][:]
sic = fh.variables['sic'][0,:,:]
#sic = fh.variables['icec'][9,:,:]
#sic = fh.variables['siconc'][0,:,:]
sic_units = fh.variables['sic'].units
fh.close()
lon_0 = lons.mean()
lat_0 = lats.mean()
#-----------------------------------------
m= Basemap(projection='spstere',resolution='f',boundinglat=-50, round=True,lon_0=180)
#-----------------------------------------
lon, lat = np.meshgrid(lons, lats)
xi, yi = m(lon, lat)
levels = np.linspace(-4,4,19, endpoint=True, dtype=int)
ax = fig.add_subplot(4,6,11)
ax.set_title('k) GISS-E2-H',  y=1.08, loc='left')
norm= matplotlib.colors.Normalize()

bwr_custom = custom_div_cmap(11)
sic = m.contourf(xi,yi,sic, cmap=bwr_custom, levels=[-4,-3,-2,-1,-0.5,0,0.5,1,2,3,4],extend='both',norm=norm)
#----------------------------------------
m.drawlsmask()
m.drawcoastlines()
m.drawparallels(np.arange(-90.,90.,10.),color='silver')#,labels=[True,True,False,False])
m.drawmeridians(np.arange(0.,360.,20.),color='silver')#,labels=[True,True,True,True])
#----------------------------------------
#----------------------------------------
sic = '/home/leticia/Documentos/leticia_dados_CMIP/dados_CMIP6/giss/tendencia/fevregres.nc'
fh = Dataset(sic, mode='r')
lons = fh.variables['lon'][:]
lats = fh.variables['lat'][:]
sic = fh.variables['siconc'][0,:,:]
#sic = fh.variables['icec'][9,:,:]
#sic = fh.variables['siconc'][0,:,:]
sic_units = fh.variables['siconc'].units
fh.close()
lon_0 = lons.mean()
lat_0 = lats.mean()
#-----------------------------------------
m= Basemap(projection='spstere',resolution='f',boundinglat=-50, round=True,lon_0=180)
#-----------------------------------------
lon, lat = np.meshgrid(lons, lats)
xi, yi = m(lon, lat)
levels = np.linspace(-4,4,19,  endpoint=True, dtype=int)
ax = fig.add_subplot(4,6,12)
ax.set_title('l) GISS-E2-1-H',  y=1.08, loc='left')
norm= matplotlib.colors.Normalize()

bwr_custom = custom_div_cmap(11)
sic = m.contourf(xi,yi,sic, cmap=bwr_custom, levels=[-4,-3,-2,-1,-0.5,0,0.5,1,2,3,4],extend='both',norm=norm)
#----------------------------------------
#----------------------------------------
m.drawlsmask()
m.drawcoastlines()
m.drawparallels(np.arange(-90.,90.,10.),color='silver')#,labels=[True,True,False,False])
m.drawmeridians(np.arange(0.,360.,20.),color='silver')#,labels=[True,True,True,True])

sic = '/home/leticia/Documentos/leticia_dados_CMIP/dados_CMIP5/hadgem/tendencia/fevregres.nc'
fh = Dataset(sic, mode='r')
lons = fh.variables['lon'][:]
lats = fh.variables['lat'][:]
sic = fh.variables['sic'][0,:,:]
#sic = fh.variables['icec'][9,:,:]
#sic = fh.variables['siconc'][0,:,:]
sic_units = fh.variables['sic'].units
fh.close()
lon_0 = lons.mean()
lat_0 = lats.mean()
#-----------------------------------------
m= Basemap(projection='spstere',resolution='f',boundinglat=-50, round=True,lon_0=180)
#-----------------------------------------
lon, lat = np.meshgrid(lons, lats)
xi, yi = m(lon, lat)
levels = np.linspace(-4,4,19, endpoint=True, dtype=int)
ax = fig.add_subplot(4,6,13)
ax.set_title('m) HadCM3',  y=1.08, loc='left')
norm= matplotlib.colors.Normalize()

bwr_custom = custom_div_cmap(11)
sic = m.contourf(xi,yi,sic, cmap=bwr_custom, levels=[-4,-3,-2,-1,-0.5,0,0.5,1,2,3,4],extend='both',norm=norm)
#----------------------------------------
m.drawlsmask()
m.drawcoastlines()
m.drawparallels(np.arange(-90.,90.,10.),color='silver')#,labels=[True,True,False,False])
m.drawmeridians(np.arange(0.,360.,20.),color='silver')#,labels=[True,True,True,True])
#----------------------------------------
sic = '/home/leticia/Documentos/leticia_dados_CMIP/dados_CMIP6/hadgem/tendencia/fevregres.nc'
fh = Dataset(sic, mode='r')
lons = fh.variables['lon'][:]
lats = fh.variables['lat'][:]
sic = fh.variables['siconc'][0,:,:]
#sic = fh.variables['icec'][9,:,:]
#sic = fh.variables['siconc'][0,:,:]
sic_units = fh.variables['siconc'].units
fh.close()
lon_0 = lons.mean()
lat_0 = lats.mean()
#-----------------------------------------
m= Basemap(projection='spstere',resolution='f',boundinglat=-50, round=True,lon_0=180)
#-----------------------------------------
lon, lat = np.meshgrid(lons, lats)
xi, yi = m(lon, lat)
levels = np.linspace(-4,4,19, endpoint=True, dtype=int)
ax = fig.add_subplot(4,6,14)
ax.set_title('n) HadGEM3-GC31-LL',  y=1.08, loc='left')
norm= matplotlib.colors.Normalize()

bwr_custom = custom_div_cmap(11)
sic = m.contourf(xi,yi,sic, cmap=bwr_custom, levels=[-4,-3,-2,-1,-0.5,0,0.5,1,2,3,4],extend='both',norm=norm)
#----------------------------------------
m.drawlsmask()
m.drawcoastlines()
m.drawparallels(np.arange(-90.,90.,10.),color='silver')#,labels=[True,True,False,False])
m.drawmeridians(np.arange(0.,360.,20.),color='silver')#,labels=[True,True,True,True])

#----------------------------------------
sic = '/home/leticia/Documentos/leticia_dados_CMIP/dados_CMIP5/IPSL/tendencia/fevregres.nc'
fh = Dataset(sic, mode='r')
lons = fh.variables['lon'][:]
lats = fh.variables['lat'][:]
sic = fh.variables['sic'][0,:,:]
#sic = fh.variables['icec'][9,:,:]
#sic = fh.variables['siconc'][0,:,:]
sic_units = fh.variables['sic'].units
fh.close()
lon_0 = lons.mean()
lat_0 = lats.mean()
#-----------------------------------------
m= Basemap(projection='spstere',resolution='f',boundinglat=-50, round=True,lon_0=180)
#-----------------------------------------
lon, lat = np.meshgrid(lons, lats)
xi, yi = m(lon, lat)
levels = np.linspace(-4,4,19, endpoint=True, dtype=int)
ax = fig.add_subplot(4,6,15)
ax.set_title('o) IPSL-CM5A-LR',  y=1.08, loc='left')
norm= matplotlib.colors.Normalize()

bwr_custom = custom_div_cmap(11)
sic = m.contourf(xi,yi,sic, cmap=bwr_custom, levels=[-4,-3,-2,-1,-0.5,0,0.5,1,2,3,4],extend='both',norm=norm)
#----------------------------------------
m.drawlsmask()
m.drawcoastlines()
m.drawparallels(np.arange(-90.,90.,10.),color='silver')#,labels=[True,True,False,False])
m.drawmeridians(np.arange(0.,360.,20.),color='silver')#,labels=[True,True,True,True])
#----------------------------------------

sic = '/home/leticia/Documentos/leticia_dados_CMIP/dados_CMIP6/IPSL/tendencia/fevregres.nc'
fh = Dataset(sic, mode='r')
lons = fh.variables['lon'][:]
lats = fh.variables['lat'][:]
sic = fh.variables['siconc'][0,:,:]
#sic = fh.variables['icec'][9,:,:]
#sic = fh.variables['siconc'][0,:,:]
sic_units = fh.variables['siconc'].units
fh.close()
lon_0 = lons.mean()
lat_0 = lats.mean()
#-----------------------------------------
m= Basemap(projection='spstere',resolution='f',boundinglat=-50, round=True,lon_0=180)
#-----------------------------------------
lon, lat = np.meshgrid(lons, lats)
xi, yi = m(lon, lat)
levels = np.linspace(-4,4,19, endpoint=True, dtype=int)
ax = fig.add_subplot(4,6,16)
ax.set_title('p) IPSL-CM6A-LR',  y=1.08, loc='left')
norm= matplotlib.colors.Normalize()

bwr_custom = custom_div_cmap(11)
sic = m.contourf(xi,yi,sic, cmap=bwr_custom, levels=[-4,-3,-2,-1,-0.5,0,0.5,1,2,3,4],extend='both',norm=norm)
#----------------------------------------
m.drawlsmask()
m.drawcoastlines()
m.drawparallels(np.arange(-90.,90.,10.),color='silver')#,labels=[True,True,False,False])
m.drawmeridians(np.arange(0.,360.,20.),color='silver')#,labels=[True,True,True,True])
#----------------------------------------
#----------------------------------------
sic = '/home/leticia/Documentos/leticia_dados_CMIP/dados_CMIP5/MIROC/tendencia/fevregres.nc'
fh = Dataset(sic, mode='r')
lons = fh.variables['lon'][:]
lats = fh.variables['lat'][:]
sic = fh.variables['sic'][0,:,:]
#sic = fh.variables['icec'][9,:,:]
#sic = fh.variables['siconc'][0,:,:]
sic_units = fh.variables['sic'].units
fh.close()
lon_0 = lons.mean()
lat_0 = lats.mean()
#-----------------------------------------
m= Basemap(projection='spstere',resolution='f',boundinglat=-50, round=True,lon_0=180)
#-----------------------------------------
lon, lat = np.meshgrid(lons, lats)
xi, yi = m(lon, lat)
levels = np.linspace(-4,4,19,  endpoint=True, dtype=int)
ax = fig.add_subplot(4,6,17)
ax.set_title('q) MIROC5',  y=1.08, loc='left')
norm= matplotlib.colors.Normalize()

bwr_custom = custom_div_cmap(11)
sic = m.contourf(xi,yi,sic, cmap=bwr_custom, levels=[-4,-3,-2,-1,-0.5,0,0.5,1,2,3,4],extend='both',norm=norm)
#----------------------------------------
m.drawlsmask()
m.drawcoastlines()
m.drawparallels(np.arange(-90.,90.,10.),color='silver')#,labels=[True,True,False,False])
m.drawmeridians(np.arange(0.,360.,20.),color='silver')#,labels=[True,True,True,True])
#----------------------------------------
#----------------------------------------
sic = '/home/leticia/Documentos/leticia_dados_CMIP/dados_CMIP6/MIROC/tendencia/fevregres.nc'
fh = Dataset(sic, mode='r')
lons = fh.variables['lon'][:]
lats = fh.variables['lat'][:]
sic = fh.variables['siconc'][0,:,:]
#sic = fh.variables['icec'][9,:,:]
#sic = fh.variables['siconc'][0,:,:]
sic_units = fh.variables['siconc'].units
fh.close()
lon_0 = lons.mean()
lat_0 = lats.mean()
#-----------------------------------------
m= Basemap(projection='spstere',resolution='f',boundinglat=-50, round=True,lon_0=180)
#----------------------------------------
lon, lat = np.meshgrid(lons, lats)
xi, yi = m(lon, lat)
levels = np.linspace(-4,4,19, endpoint=True, dtype=int)
ax = fig.add_subplot(4,6,18)
ax.set_title('r) MIROC6',  y=1.08, loc='left')
norm= matplotlib.colors.Normalize()

bwr_custom = custom_div_cmap(11)
sic = m.contourf(xi,yi,sic, cmap=bwr_custom, levels=[-4,-3,-2,-1,-0.5,0,0.5,1,2,3,4],extend='both',norm=norm)
#----------------------------------------
m.drawlsmask()
m.drawcoastlines()
m.drawparallels(np.arange(-90.,90.,10.),color='silver')#,labels=[True,True,False,False])
m.drawmeridians(np.arange(0.,360.,20.),color='silver')#,labels=[True,True,True,True])
#----------------------------------------
#----------------------------------------
sic = '/home/leticia/Documentos/leticia_dados_CMIP/dados_CMIP5/MPI/tendencia/fevregres.nc'
fh = Dataset(sic, mode='r')
lons = fh.variables['lon'][:]
lats = fh.variables['lat'][:]
sic = fh.variables['sic'][0,:,:]
#sic = fh.variables['icec'][9,:,:]
#sic = fh.variables['siconc'][0,:,:]
sic_units = fh.variables['sic'].units
fh.close()
lon_0 = lons.mean()
lat_0 = lats.mean()
#-----------------------------------------
m= Basemap(projection='spstere',resolution='f',boundinglat=-50, round=True,lon_0=180)
#----------------------------------------
lon, lat = np.meshgrid(lons, lats)
xi, yi = m(lon, lat)
levels = np.linspace(-4,4,19, endpoint=True, dtype=int)
ax = fig.add_subplot(4,6,19)
ax.set_title('s) MPI-ESM-LR',  y=1.08, loc='left')
norm= matplotlib.colors.Normalize()

bwr_custom = custom_div_cmap(11)
sic = m.contourf(xi,yi,sic, cmap=bwr_custom, levels=[-4,-3,-2,-1,-0.5,0,0.5,1,2,3,4],extend='both',norm=norm)
#----------------------------------------
m.drawlsmask()
m.drawcoastlines()
m.drawparallels(np.arange(-90.,90.,10.),color='silver')#,labels=[True,True,False,False])
m.drawmeridians(np.arange(0.,360.,20.),color='silver')#,labels=[True,True,True,True])
#----------------------------------------
sic = '/home/leticia/Documentos/leticia_dados_CMIP/dados_CMIP6/MPI/tendencia/fevregres.nc'
fh = Dataset(sic, mode='r')
lons = fh.variables['lon'][:]
lats = fh.variables['lat'][:]
sic = fh.variables['siconc'][0,:,:]
#sic = fh.variables['icec'][9,:,:]
#sic = fh.variables['siconc'][0,:,:]
sic_units = fh.variables['siconc'].units
fh.close()
lon_0 = lons.mean()
lat_0 = lats.mean()
#-----------------------------------------
m= Basemap(projection='spstere',resolution='f',boundinglat=-50, round=True,lon_0=180)
#-----------------------------------------
lon, lat = np.meshgrid(lons, lats)
xi, yi = m(lon, lat)
levels = np.linspace(-4,4,19, endpoint=True, dtype=int)
ax = fig.add_subplot(4,6,20)
ax.set_title('u) MPI-ESM1-2-LR',  y=1.08, loc='left')
norm= matplotlib.colors.Normalize()

bwr_custom = custom_div_cmap(11)
sic = m.contourf(xi,yi,sic, cmap=bwr_custom, levels=[-4,-3,-2,-1,-0.5,0,0.5,1,2,3,4],extend='both',norm=norm)
#----------------------------------------
m.drawlsmask()
m.drawcoastlines()
m.drawparallels(np.arange(-90.,90.,10.),color='silver')#,labels=[True,True,False,False])
m.drawmeridians(np.arange(0.,360.,20.),color='silver')#,labels=[True,True,True,True])
#----------------------------------------
#----------------------------------------
#----------------------------------------
sic = '/home/leticia/Documentos/leticia_dados_CMIP/dados_CMIP5/NCAR/tendencia/fevregres.nc'
fh = Dataset(sic, mode='r')
lons = fh.variables['lon'][:]
lats = fh.variables['lat'][:]
sic = fh.variables['sic'][0,:,:]
#sic = fh.variables['icec'][9,:,:]
#sic = fh.variables['siconc'][0,:,:]
sic_units = fh.variables['sic'].units
fh.close()
lon_0 = lons.mean()
lat_0 = lats.mean()
#-----------------------------------------
m= Basemap(projection='spstere',resolution='f',boundinglat=-50, round=True,lon_0=180)
#----------------------------------------
lon, lat = np.meshgrid(lons, lats)
xi, yi = m(lon, lat)
levels = np.linspace(-4,4,19, endpoint=True, dtype=int)
ax = fig.add_subplot(4,6,21)
ax.set_title('v) NCAR-CCSM4',  y=1.08, loc='left')
norm= matplotlib.colors.Normalize()

bwr_custom = custom_div_cmap(11)
sic = m.contourf(xi,yi,sic, cmap=bwr_custom, levels=[-4,-3,-2,-1,-0.5,0,0.5,1,2,3,4],extend='both',norm=norm)
#----------------------------------------
m.drawlsmask()
m.drawcoastlines()
m.drawparallels(np.arange(-90.,90.,10.),color='silver')#,labels=[True,True,False,False])
m.drawmeridians(np.arange(0.,360.,20.),color='silver')#,labels=[True,True,True,True])
#----------------------------------------
sic = '/home/leticia/Documentos/leticia_dados_CMIP/dados_CMIP6/NCAR/tendencia/fevregres.nc'
fh = Dataset(sic, mode='r')
lons = fh.variables['lon'][:]
lats = fh.variables['lat'][:]
sic = fh.variables['siconc'][0,:,:]
#sic = fh.variables['icec'][9,:,:]
#sic = fh.variables['siconc'][0,:,:]
sic_units = fh.variables['siconc'].units
fh.close()
lon_0 = lons.mean()
lat_0 = lats.mean()
#-----------------------------------------
m= Basemap(projection='spstere',resolution='f',boundinglat=-50, round=True,lon_0=180)
#-----------------------------------------
lon, lat = np.meshgrid(lons, lats)
xi, yi = m(lon, lat)
levels = np.linspace(-4,4,19, endpoint=True, dtype=int)
ax = fig.add_subplot(4,6,22)
ax.set_title('x) NCAR-CESM2',  y=1.08, loc='left')
norm= matplotlib.colors.Normalize()

bwr_custom = custom_div_cmap(11)
sic = m.contourf(xi,yi,sic, cmap=bwr_custom, levels=[-4,-3,-2,-1,-0.5,0,0.5,1,2,3,4],extend='both',norm=norm)
#----------------------------------------
m.drawlsmask()
m.drawcoastlines()
m.drawparallels(np.arange(-90.,90.,10.),color='silver')#,labels=[True,True,False,False])
m.drawmeridians(np.arange(0.,360.,20.),color='silver')#,labels=[True,True,True,True])
#----------------------------------------
sic = '/home/leticia/Documentos/leticia_dados_CMIP/sate_V4/historical/tendencia/fevregres.nc'
fh = Dataset(sic, mode='r')
lons = fh.variables['longitude'][:]
lats = fh.variables['latitude'][:]
sic = fh.variables['sic'][0,:,:]
#sic = fh.variables['icec'][9,:,:]
#sic = fh.variables['siconc'][0,:,:]
sic_units = fh.variables['sic'].units
fh.close()
lon_0 = lons.mean()
lat_0 = lats.mean()
#-----------------------------------------
m= Basemap(projection='spstere',resolution='f',boundinglat=-50, round=True,lon_0=180)
#-----------------------------------------
lon, lat = np.meshgrid(lons, lats)
xi, yi = m(lon, lat)
levels = np.linspace(-4,4,19, endpoint=True, dtype=int)
ax = fig.add_subplot(4,6,23)
ax.set_title('w) Satellite',  y=1.08, loc='left')
norm= matplotlib.colors.Normalize()

bwr_custom = custom_div_cmap(11)
sic = m.contourf(xi,yi,sic, cmap=bwr_custom, levels=[-4,-3,-2,-1,-0.5,0,0.5,1,2,3,4],extend='both',norm=norm)
#----------------------------------------
m.drawlsmask()
m.drawcoastlines()
m.drawparallels(np.arange(-90.,90.,10.),color='silver')#,labels=[True,True,False,False])
m.drawmeridians(np.arange(0.,360.,20.),color='silver')#,labels=[True,True,True,True])

#----------------------------------------
cbar_ax = fig.add_axes([0.92, 0.35, 0.01, 0.3],title='')
ticks=[-4,-3,-2,-1,-0.5,0,0.5,1,2,3,4]
fig.colorbar(sic,cax=cbar_ax,ticks=ticks)
plt.savefig('trend_fev.jpeg')
# Out:
# /home/leticia/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:22: MatplotlibDeprecationWarning:
# The dedent function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use inspect.cleandoc instead.
# /home/leticia/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:67: MatplotlibDeprecationWarning:
# The dedent function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use inspect.cleandoc instead.
# /home/leticia/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:97: MatplotlibDeprecationWarning:
# The dedent function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use inspect.cleandoc instead.
# /home/leticia/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:126: MatplotlibDeprecationWarning:
# The dedent function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use inspect.cleandoc instead.
# ...
